# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
nineoneone_df = pd.read_csv("../resources/Call_Data.csv")

# %%
nineoneone_df.head(5)
# Out:
#    CAD Event Number                 Event Clearance Description  \
# 0     2019000433917                         ASSISTANCE RENDERED
# 1     2020000104380                         ASSISTANCE RENDERED
# 2     2019000445831                           OTHER REPORT MADE
# 3     2018000337690    UNABLE TO LOCATE INCIDENT OR COMPLAINANT
# 4     2020000028755  CITATION ISSUED (CRIMINAL OR NON-CRIMINAL)
#
#                   Call Type  Priority  \
# 0  TELEPHONE OTHER, NOT 911         2
# 1                    ONVIEW         7
# 2                    ONVIEW         2
# 3                       911         3
# 4                    ONVIEW         7
#
#                                  Initial Call Type  \
# 0  HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)
# 1     PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY
# 2            ASSIST OTHER AGENCY - ROUTINE SERVICE
# 3    ALARM - AUDIBLE AUTOMOBILE (UNOCC/ANTI-THEFT)
# 4          TRAFFIC STOP - OFFICER INITIATED ONVIEW
#
# ...

# %%
nineoneone_df['Original Time Queued'] =  pd.to_datetime(nineoneone_df['Original Time Queued'], format="%m/%d/%Y %H:%M:%S %p")#, errors="ignore")
nineoneone_df['Arrived Time'] =  pd.to_datetime(nineoneone_df['Arrived Time'], format="%b %d %Y %H:%M:%S:%f%p")#, errors="ignore")
nineoneone_df["time_to_arrival"] = nineoneone_df["Arrived Time"] - nineoneone_df["Original Time Queued"]
nineoneone_df["time_to_arrival"] = nineoneone_df["time_to_arrival"].dt.seconds.div(60)
nineoneone_df['call_hour'] = nineoneone_df['Original Time Queued'].dt.hour
# nineoneone_df[[ "Original Time Queued", "Arrived Time", "time_to_arrival", 'call_hour']]
nineoneone_df.head()
# Out:
#    CAD Event Number                 Event Clearance Description  \
# 0     2019000433917                         ASSISTANCE RENDERED
# 1     2020000104380                         ASSISTANCE RENDERED
# 2     2019000445831                           OTHER REPORT MADE
# 3     2018000337690    UNABLE TO LOCATE INCIDENT OR COMPLAINANT
# 4     2020000028755  CITATION ISSUED (CRIMINAL OR NON-CRIMINAL)
#
#                   Call Type  Priority  \
# 0  TELEPHONE OTHER, NOT 911         2
# 1                    ONVIEW         7
# 2                    ONVIEW         2
# 3                       911         3
# 4                    ONVIEW         7
#
#                                  Initial Call Type  \
# 0  HAZ - POTENTIAL THRT TO PHYS SAFETY (NO HAZMAT)
# 1     PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY
# 2            ASSIST OTHER AGENCY - ROUTINE SERVICE
# 3    ALARM - AUDIBLE AUTOMOBILE (UNOCC/ANTI-THEFT)
# 4          TRAFFIC STOP - OFFICER INITIATED ONVIEW
#
# ...

# %%
nineoneone_df.plot.scatter(x='call_hour',
                      y='time_to_arrival',
                       colormap='viridis'
                          )
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
nineoneone_df.plot.scatter(x='Final Call Type',
                      y='time_to_arrival',
                       colormap='viridis',
                        figsize=(15,8)
                          )
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
noon_response_times = nineoneone_df["time_to_arrival"]
noon_response_times = nineoneone_df[nineoneone_df['call_hour']==12]
boxplot = noon_response_times.boxplot(column=['time_to_arrival'])
# noon_response_times

# %%
remove_zeroes = nineoneone_df[nineoneone_df['time_to_arrival']!=0]
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(20,10)})
ax = sns.boxplot(x="call_hour", y="time_to_arrival", data=remove_zeroes, fliersize= 0)
ax.set(ylim=(-5, 400))
# Out:
# [(-5.0, 400.0)]
